# %% [markdown]
# # **Calcul des moyennes des UE**

# %% [markdown]
# demande les notes de chaque R de chaque UE
# a chaque input aditioner a la precedente et diviser par le nb d'input par ue

# %%
cache=float(0) #I define all variables
note=float(0)
coeff=float(0)
compteur=int(101) #set compteur to 101 for R 101-115
resultat=float(0)

while compteur != 116: #first while to compute the coeff of the R's
    addition=float(input("saisisez votre note pour R{}".format(compteur))) #ask grade
    coeff=float(input("saisisez votre coeff pour R{}".format(compteur))) #ask coeff
    compteur=compteur+1 #increase by 1 R
    cache=cache+(addition*coeff) #put in cache the result
    
compteur=11 #set compteur to 11 for the SAE 11-16
while compteur != 17: #second while to compute the coeff of the SAE's
    addition=float(input("saisisez votre note pour SAE{}".format(compteur))) #ask grade
    coeff=float(input("saisisez votre coeff pour SAE{}".format(compteur))) #ask coeff
    compteur=compteur+1 #increase by 1 R
    cache=cache+(addition*coeff) #add to cache the result
resultat=cache/21 #divide the cache by the number of grades
resultat #show the final result
# Out:
# saisisez votre note pour R101 10
# saisisez votre coeff pour R101 1
# saisisez votre note pour R102 20
# saisisez votre coeff pour R102 1
# saisisez votre note pour R103 2
# saisisez votre coeff pour R103 2
# saisisez votre note pour R104 2
# saisisez votre coeff pour R104 2
# saisisez votre note pour R105 2
# saisisez votre coeff pour R105 2
# saisisez votre note pour R106 2
# saisisez votre coeff pour R106 2
# saisisez votre note pour R107 2
# saisisez votre coeff pour R107 2
# saisisez votre note pour R108 2
# saisisez votre coeff pour R108 2
# saisisez votre note pour R109 22
# saisisez votre coeff pour R109 2
# saisisez votre note pour R110 2
# saisisez votre coeff pour R110 2
# saisisez votre note pour R111 2
# saisisez votre coeff pour R111 2
# saisisez votre note pour R112 2
# saisisez votre coeff pour R112 2
# saisisez votre note pour R113 2
# saisisez votre coeff pour R113 2
# saisisez votre note pour R114 2
# saisisez votre coeff pour R114 2
# ...
